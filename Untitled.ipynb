# %%
import pandas as pd

# %%
# %run helper_functions.ipynb
# %run creating_Dataframes.ipynb
# %run fixtures.ipynb
# %run training_set.ipynb

# %% [markdown]
# **get latest GW**

# %%
#find latest GW
last_gw = all_season_df['gw'][all_season_df['season'] == '1920'].max()

if np.isnan(last_gw):
    last_gw = 1
else:
    last_gw = last_gw + 1
# Out:
# 30

# %% [markdown]
# **get DF for latest GW**

# %%
df_latest_gw = build_season(season_paths[3],season_names[3], teams, all_players, [last_gw])

# %%
df_latest_gw
# Out:
#               player  gw  minutes                      team  position  \
# 0     Aaron_Connolly  30       19  Brighton and Hove Albion         4
# 1    Aaron_Cresswell  30       90           West Ham United         2
# 2       Aaron_Lennon  30        0                   Burnley         3
# 3         Aaron_Mooy  30       45  Brighton and Hove Albion         3
# 4     Aaron_Ramsdale  30       90               Bournemouth         1
# ..               ...  ..      ...                       ...       ...
# 757      Zech_Medley  30        0                   Arsenal         2
# 758      Zech_Medley  30        0                   Arsenal         2
# 759   Çaglar_Söyüncü  30       90            Leicester City         2
# 760     Ørjan_Nyland  30       90               Aston Villa         1
# 761     Ørjan_Nyland  30       90               Aston Villa         1
#
#                 opponent_team  was_home  total_points  assists  bonus  ...  \
# 0                     Arsenal      True             4        1      0  ...
# 1     Wolverhampton Wanderers      True             1        0      0  ...
# 2             Manchester City     False             0        0      0  ...
# 3                     Arsenal      True             0        0      0  ...
# 4              Crystal Palace      True             1        0      0  ...
# ..                        ...       ...           ...      ...    ...  ...
# 757           Manchester City     False             0        0      0  ...
# 758  Brighton and Hove Albion     False             0        0      0  ...
# 759                   Watford     False             2        0      0  ...
# 760          Sheffield United      True             6        0      0  ...
# 761                   Chelsea      True             2        0      0  ...
#
#      selected  team_a_score  team_h_score  threat  transfers_balance  \
# 0      132408             1             2     0.0              41747
# 1       85564             2             0     2.0              -3688
# 2        6807             0             5     0.0                333
# 3       38018             1             2    19.0             -10764
# 4      274431             2             0     0.0               8952
# ..        ...           ...           ...     ...                ...
# 757         0             0             3     0.0                  0
# 758         0             1             2     0.0                  0
# 759   1148862             1             1     7.0             -40611
# 760     24213             0             0     0.0               8602
# 761     24213             2             1     0.0               8602
#
#      transfers_in  transfers_out  yellow_cards          kickoff_time  season
# 0           70743          28996             0  2020-06-20T14:00:00Z    1920
# 1           10607          14295             0  2020-06-20T16:30:00Z    1920
# 2             817            484             0  2020-06-22T19:00:00Z    1920
# 3            3284          14048             1  2020-06-20T14:00:00Z    1920
# 4           64265          55313             0  2020-06-20T18:45:00Z    1920
# ..            ...            ...           ...                   ...     ...
# 757             0              0             0  2020-06-17T19:15:00Z    1920
# 758             0              0             0  2020-06-20T14:00:00Z    1920
# 759        194113         234724             0  2020-06-20T11:30:00Z    1920
# 760         12025           3423             0  2020-06-17T17:00:00Z    1920
# 761         12025           3423             0  2020-06-21T15:15:00Z    1920
#
# [762 rows x 32 columns]
