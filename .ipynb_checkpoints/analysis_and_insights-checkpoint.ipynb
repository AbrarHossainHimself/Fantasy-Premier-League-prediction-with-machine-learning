# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %run Optimal_FPL_prediction_project.ipynb
# %run Creating_Dataframes.ipynb

# %%
highest_point_getters = all_season_df.nlargest(100, ['total_points'])
highest_point_getters
f, ax = plt.subplots(figsize=(12,8))
ax = sns.scatterplot(x="now_cost", y='total_points', data=highest_point_getters)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-2b80944bad01> in <module>
#       2 highest_point_getters
#       3 f, ax = plt.subplots(figsize=(12,8))
# ----> 4 ax = sns.scatterplot(x="now_cost", y='total_points', data=highest_point_getters)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1333         x_bins=x_bins, y_bins=y_bins,
#    1334         estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1335         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#    1336     )
#    1337
#
# ...

# %%
highest_point_getters_low_cost = highest_point_getters.nsmallest(24, ['now_cost'])
highest_point_getters_low_cost
# Out:
#       first_name          second_name  goals_scored  assists  total_points  \
# 457         John            Lundstram             4        4           135
# 143         Nick                 Pope             0        0           160
# 454       George              Baldock             2        4           138
# 451         Enda              Stevens             2        4           139
# 470         Dean            Henderson             0        1           155
# 134        James            Tarkowski             2        3           134
# 632    Rui Pedro  dos Santos Patrício             0        0           143
# 267       Kasper           Schmeichel             0        0           148
# 44          Jack             Grealish             7        7           133
# 623         Matt              Doherty             4        6           151
# 424        Teemu                Pukki            11        3           136
# ...
