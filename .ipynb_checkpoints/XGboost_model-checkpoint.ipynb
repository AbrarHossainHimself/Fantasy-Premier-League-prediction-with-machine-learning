# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\Asus\PycharmProjects\FPL Project\my_data\final_dataset.csv')

# %%
#check for null values
data.isnull().sum()
# Out:
# player                0
# gw                    0
# minutes               0
# team                  0
# position              0
# position_name         0
# opponent_team         0
# was_home              0
# total_points          0
# assists               0
# bonus                 0
# bps                   0
# clean_sheets          0
# creativity            0
# goals_conceded        0
# goals_scored          0
# ict_index             0
# influence             0
# own_goals             0
# penalties_missed      0
# penalties_saved       0
# red_cards             0
# saves                 0
# selected              0
# team_a_score         59
# team_h_score         59
# threat                0
# transfers_balance     0
# transfers_in          0
# transfers_out         0
# yellow_cards          0
# kickoff_time          0
# season                0
# xG                    0
# xGA                   0
# npxG                  0
# npxGA                 0
# dtype: int64

# %%
data.columns
# Out:
# Index(['player', 'gw', 'minutes', 'team', 'position', 'position_name',
#        'opponent_team', 'was_home', 'total_points', 'assists', 'bonus', 'bps',
#        'clean_sheets', 'creativity', 'goals_conceded', 'goals_scored',
#        'ict_index', 'influence', 'own_goals', 'penalties_missed',
#        'penalties_saved', 'red_cards', 'saves', 'selected', 'team_a_score',
#        'team_h_score', 'threat', 'transfers_balance', 'transfers_in',
#        'transfers_out', 'yellow_cards', 'kickoff_time', 'season', 'xG', 'xGA',
#        'npxG', 'npxGA'],
#       dtype='object')

# %% [markdown]
# **Rows with nan values**

# %%
data[data.isnull().any(axis =1)]
# Out:
#                                         player  gw  minutes             team  \
# 83874                              John_Stones  29        0  Manchester City
# 83876                              David_Silva  29        0  Manchester City
# 83878                              Bukayo_Saka  29        0          Arsenal
# 83880                           Sead_Kolasinac  29        0          Arsenal
# 83900                               Bernd_Leno  29        0          Arsenal
# 83906                              Kyle_Walker  29        0  Manchester City
# 83909                Pierre-Emerick_Aubameyang  29        0          Arsenal
# 83916                           Kieran_Tierney  29        0          Arsenal
# 83924                           Edward_Nketiah  29        0          Arsenal
# 83948                Daniel_Ceballos Fernández  29        0          Arsenal
# 83956                               Pablo_Marí  29        0          Arsenal
# ...

# %% [markdown]
# **Test and Training Data splitting**

# %%
from sklearn.model_selection import train_test_split

y = data['total_points']

X = data.drop(data[['kickoff_time', 'total_points','position_name']], axis =1)# dropping columns that are not relevant

# Separate data into training and validation sets
X_train, X_valid, y_train, y_valid = train_test_split(X, y)

# %% [markdown]
# **Getting columns with categorical values**

# %%
# Get list of categorical variables
s = (X_train.dtypes == 'object')
object_cols = list(s[s].index)

print("Categorical variables:")
print(object_cols)
# Out:
# Categorical variables:
# ['player', 'team', 'opponent_team']

# %% [markdown]
# **One hot encoding categorical values**

# %%
from sklearn.preprocessing import OneHotEncoder

# Apply one-hot encoder to each column with categorical data
OH_encoder = OneHotEncoder(handle_unknown='ignore', sparse=False)
OH_cols_train = pd.DataFrame(OH_encoder.fit_transform(X_train[object_cols]))
OH_cols_valid = pd.DataFrame(OH_encoder.transform(X_valid[object_cols]))

# One-hot encoding removed index; put it back
OH_cols_train.index = X_train.index
OH_cols_valid.index = X_valid.index

# Remove categorical columns (will replace with one-hot encoding)
num_X_train = X_train.drop(object_cols, axis=1)
num_X_valid = X_valid.drop(object_cols, axis=1)

# Add one-hot encoded columns to numerical features
OH_X_train = pd.concat([num_X_train, OH_cols_train], axis=1)
OH_X_valid = pd.concat([num_X_valid, OH_cols_valid], axis=1)

# %% [markdown]
# **Imputing missing values**

# %%
from sklearn.impute import SimpleImputer

# Imputation
my_imputer = SimpleImputer()
imputed_X_train = pd.DataFrame(my_imputer.fit_transform(OH_X_train))
imputed_X_valid = pd.DataFrame(my_imputer.transform(OH_X_valid))

# Imputation removed column names; put them back
imputed_X_train.columns = OH_X_train.columns
imputed_X_valid.columns = OH_X_valid.columns

# %%
data.shape
# Out:
# (84557, 37)

# %%
X_train.shape
# Out:
# (63417, 35)

# %%
X_valid.shape
# Out:
# (21140, 35)

# %%
# !pip install xgboost

# %% [markdown]
# **Fitting the model**

# %%
from xgboost import XGBRegressor

my_model_1 = XGBRegressor()
my_model_1.fit(imputed_X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %% [markdown]
# **Prediction Time**

# %%
# Get predictions
predictions_1 = my_model_1.predict(imputed_X_valid) # Your code here

# %% [markdown]
# **Mean Absolute Error**

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import accuracy_score

# Calculate MAE
mae_1 = mean_absolute_error(y_valid, predictions_1) # Your code here

# Uncomment to print MAE
print("Mean Absolute Error:" , mae_1)

#accuracy
accuracy = accuracy_score(y_valid, predictions_1)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Mean Absolute Error: 0.0264721459674745

# %%
predictions_1
# Out:
# array([1.2199581e-03, 9.9685526e-01, 2.0245123e+00, ..., 1.9998304e+00,
#        6.0089016e+00, 1.9935044e+00], dtype=float32)

# %%
max(predictions_1)
# Out:
# 21.904285

# %%
results = X_valid.merge(y_valid.to_frame(), left_index=True, right_index=True)
results['preds'] = predictions_1
results
# Out:
#                          player  gw  minutes                     team  \
# 38867               Kyle_Taylor  27        0              Bournemouth
# 39040            Saido_Berahino  27       45               Stoke City
# 5846              Claudio_Bravo  11       90          Manchester City
# 59342  Rui Pedro_da Rocha Fonte  24        0                   Fulham
# 55994               Will_Norris  18        0  Wolverhampton Wanderers
# ...                         ...  ..      ...                      ...
# 14582           Dominic_Solanke  25        0                  Chelsea
# 70867              James_Garner   6        0        Manchester United
# 23612             Stefano_Okaka  38       90                  Watford
# 24965               Jonas_Lössl   3       90        Huddersfield Town
# 3489             Damien_Delaney   7       90           Crystal Palace
#
#        position             opponent_team  was_home  assists  bonus  bps  ...  \
# ...

# %%
a =results[['player', 'gw', 'total_points', 'season']].sort_values(by=['total_points'])

# %%
a
# Out:
#                     player  gw  total_points  season
# 81957  Oleksandr_Zinchenko  25            -3    1920
# 47190      Terence_Kongolo   2            -3    1819
# 61153          Tommy_Smith  27            -3    1819
# 11778        Simon_Francis  20            -2    1617
# 75987        Mamadou_Sakho  15            -2    1920
# ...                    ...  ..           ...     ...
# 55706        Jesse_Lingard  18            18    1819
# 45574     Andrew_Robertson  38            18    1718
# 66545        Mohamed_Salah  36            19    1819
# 58448           Diogo_Jota  23            19    1819
# 41224        Mohamed_Salah  31            29    1718
#
# [21140 rows x 4 columns]

# %%
a[a['season'] ==1920].sort_values('total_points').tail(20)
# Out:
#                            player    gw  total_points  season
# 80707       Alisson_Ramses Becker    23            13    1920
# 79503   Gabriel Fernando_de Jesus    21            13    1920
# 75066             Aaron_Cresswell    14            14    1920
# 74622             Conor_Hourihane    13            14    1920
# 73712                 Kyle_Walker    11            14    1920
# 70633             Aaron_Cresswell     6            14    1920
# 78788             Kevin_De Bruyne    20            14    1920
# 72255               Wesley_Moraes     8            14    1920
# 70569                Serge_Aurier     5            14    1920
# 68129                Erik_Pieters     1            14    1920
# 80697             Virgil_van Dijk    23            15    1920
# 82251               Harry_Maguire    26            15    1920
# 83223         Patrick_van Aanholt    27            15    1920
# 75130               Bamidele_Alli    14            15    1920
# ...
