# %%
from pathlib import Path
import pandas as pd

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None) # to see the complete DF and not the truncated version

# %%
def build_players(path, season_paths, season_names, teams):
    season_players = []
    
    for season_path in season_paths:
        player = pd.read_csv(season_path/'players_raw.csv',
                            usecols =  ['id','first_name','second_name',
                                        'element_type','team_code',
                                        'bps','chance_of_playing_next_round',
                                        'now_cost','selected_by_percent',
                                        'transfers_in','transfers_in_event',
                                        'transfers_out','transfers_out_event'
                                       ])
        season_players.append(player)
                   
    #getting full name from first and last name 
    for player in season_players:
        player['full_name'] = player['first_name'] + '_' + player['second_name']
        player.drop(['first_name', 'second_name'], axis = 1, inplace = True)
        
    #concatenating all players from the 4 seasons into a single DF
    all_players = pd.concat(season_players, axis = 0, ignore_index = True, sort =False)
    
    #creating a series of unique names
    all_players = pd.DataFrame(all_players['full_name'].drop_duplicates())
                               
    for player, season in zip(season_players, season_names):
        all_players = all_players.merge(player, on = "full_name", how = 'left')
        all_players = all_players.rename(index=str,
                                         columns= {'id': 'id_' + season,
                                                 'element_type': 'element_type_' + season,
                                                 'team_code': 'teams_code_' + season,
                                                 'bps': 'bps_' + season,
                                                 'chance_of_playing_next_round': 'chance_of_playing_next_round_' + season,
                                                 'now_cost': 'now_cost_' + season,
                                                 'selected_by_percent': 'selected_by_percent_' + season,
                                                 'transfers_in': 'transfers_in_' + season,
                                                 'transfers_in_event': 'transfers_in_event_' + season,
                                                 'transfers_out': 'transfers_out_' + season,
                                                 'transfers_out_event': 'transfers_out_event_' + season
                                                   },inplace = True)
                                  
    return all_players

# %%
  
    #chnaging name for players with same "full_name" by addin "_alt" at the end
#     for name in all_players.loc[all_players.duplicated(['full_name'])].values:
#         name[0] = str(name[0]) + '_alt'
#         all_players.loc[all_players['full_name'].duplicated(), 'full_name'] = name[0]

# %%
path = Path('./data')
season_paths= [path/'2016-17',path/'2017-18',path/'2018-19',path/'2019-20']
season_names=['1617','1718','1819','1920'] 
teams=pd.read_csv(path/'teams.csv')

# %%
all_players = build_players(path, season_paths, season_names, teams)
all_players
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-194-6f6e4cbebc6b> in <module>
# ----> 1 all_players = build_players(path, season_paths, season_names, teams)
#       2 all_players
#
# <ipython-input-191-40562ac4afbf> in build_players(path, season_paths, season_names, teams)
#      25
#      26     for player, season in zip(season_players, season_names):
# ---> 27         all_players = all_players.merge(player, on = "full_name", how = 'left')
#      28         all_players = all_players.rename(index=str,
#      29                                          columns= {'id': 'id_' + season,
#
# AttributeError: 'NoneType' object has no attribute 'merge'

# %%
duplicateDFRow = all_players[all_players.duplicated(['full_name'])]

# %%
duplicateDFRow

# %%
for name in all_players.loc[all_players.duplicated(['full_name'])].values:
    name[0] = name[0] + '_alt'
    all_players.loc[all_players['full_name'].duplicated(), 'full_name'] = name[0]
# Out:
# Danny_Ward_alt

# %%
all_players[all_players.duplicated(['full_name'])]
# Out:
# Empty DataFrame
# Columns: [full_name, bps_1617, chance_of_playing_next_round_1617, element_type_1617, id_1617, now_cost_1617, selected_by_percent_1617, teams_code_1617, transfers_in_1617, transfers_in_event_1617, transfers_out_1617, transfers_out_event_1617, bps_1718, chance_of_playing_next_round_1718, element_type_1718, id_1718, now_cost_1718, selected_by_percent_1718, teams_code_1718, transfers_in_1718, transfers_in_event_1718, transfers_out_1718, transfers_out_event_1718, bps_1819, chance_of_playing_next_round_1819, element_type_1819, id_1819, now_cost_1819, selected_by_percent_1819, teams_code_1819, transfers_in_1819, transfers_in_event_1819, transfers_out_1819, transfers_out_event_1819, bps_1920, chance_of_playing_next_round_1920, element_type_1920, id_1920, now_cost_1920, selected_by_percent_1920, teams_code_1920, transfers_in_1920, transfers_in_event_1920, transfers_out_1920, transfers_out_event_1920]
# Index: []

# %%
for name in all_players.loc[all_players.duplicated(['full_name'])].values:
        name[0] = name[0] + '_alt'
        all_players.loc[all_players['full_name'].duplicated(), 'full_name'] = name[0]

# %%
all_players.duplicated(['full_name'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
# 30      False
# 31      False
# 32      False
# 33      False
# 34      False
# 35      False
# 36      False
# 37      False
# 38      False
# 39      False
# 40      False
# 41      False
# 42      False
# 43      False
# 44      False
# 45      False
# 46      False
# 47      False
# 48      False
# 49      False
# 50      False
# 51      False
# 52      False
# 53      False
# 54      False
# 55      False
# 56      False
# 57      False
# 58      False
# 59      False
# 60      False
# 61      False
# ...
